# %% [markdown]
# # **Lab 4.1: Neural Networks (Regression)**
#
# <hr>
#
# ## **1. Introduction**
# In previous practices, we learned how to solve classification and regression problems using traditional machine learning methods or models. In this practice, we will see how to solve these types of problems using **Neural Networks**, which are among the most commonly used methods today.
#
# These networks form the foundation of *Deep Learning* and have the capability of being highly versatile as they are composed of multiple neurons organized into layers. These neurons are also called *perceptrons*, which is why neural networks are also known as **Multilayer Perceptrons**.
#
# Just like with other models, `scikit-learn` provides a couple of classes that facilitate the use of these networks:
#
# * **MLPRegressor:** A multilayer perceptron designed to solve regression problems.
# * **MLPClassifier:** A multilayer perceptron designed to solve classification problems.
#
# For this type of model, we will not use these predefined classes since we are interested in understanding their architecture and internal functioning. For this reason, we will use a new library, [`tensorflow`](https://www.tensorflow.org/), which is one of the most widely used in Python for deep learning tasks, along with [`pytorch`](https://pytorch.org/).
#
# ### **Objectives**
# In this practice, you will learn to:
# * Create and train Neural Networks.
# * Optimize their hyperparameters.
# * Add nonlinear activation functions.
#
# We will start by installing the library in our environment.

# %%
! pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from tensorflow) (2.33.1)
# Requirement already satisfied: setuptools in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: numpy>=1.26.0 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.4.22)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)

# %% [markdown]
# One of the advantages of neural networks is that they can be trained on either a CPU or a GPU.
#
# Later on, we will see how to train one of these networks on the GPUs of the lab computers to accelerate the training process. On your personal computer, you will likely only be able to run it on a CPU.
#
# Next, we load our data once again:

# %%
import pandas as pd

seed = 2533
data = pd.read_pickle('https://raw.githubusercontent.com/AIC-Uniovi/Sistemas-Inteligentes/refs/heads/main/datasets/f1_23_monaco.pkl')

# %% [markdown]
# <hr>
#
# ## **2. Regression Problems**
#
# We will attempt to solve the same problem as in the previous practice, which is:
#
# <div class="alert alert-block alert-success">
#     <b>Create a model that, given the time in the first sector `<code>Sector1Time</code>, can predict the total lap time <code>LapTime</code>.</b>
# </div>
#
# The first step will be to create the necessary datasets to train a model.
#
# ### **2.1. Data Preprocessing**
#
#
# <hr>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Exercise:</b> Separate the X and Y from the dataframe <code>data_sector2lap</code>, split it into training and test sets (80/20) by setting a random seed, and finally <b>standardize</b> the X values.
#     <hr>
#     When X has only one column, you must use double brackets (<code>data[['column_name']]</code> instead of <code>data['column_name']</code>) for <code>StandardScaler()</code> to work correctly.
# </div>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

data_sector2lap = data[['LapTime', 'Sector1Time']].copy()
data_sector2lap['LapTime'] = data_sector2lap['LapTime'].dt.total_seconds()
data_sector2lap['Sector1Time'] = data_sector2lap['Sector1Time'].dt.total_seconds()

# Your code her
X = data_sector2lap[['Sector1Time']]
y = data_sector2lap['LapTime']

Xtr, Xte, ytr, yte = train_test_split(X, y, test_size=0.2, random_state=seed)
scaler = StandardScaler()
Xtr_s = scaler.fit_transform(Xtr)
Xte_s = scaler.transform(Xte)

# %% [markdown]
# ### **2.2. Machine Learning**
#
# With the data ready, we will train and evaluate the well-known machine learning models once again to compare them with our new system.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Exercise:</b> Train and evaluate the remaining models (<i>K-Nearest Neighbors</i>, <i>Decision Trees</i>, and <i>SVR</i>) using the following function.
# </div>

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
def evaluate_model(yte, preds_test, model_name):
    metrics = {
        "Métrica": ["MAE", "MSE", "R²"],
        "TEST": [mean_absolute_error(yte, preds_test), 
                 mean_squared_error(yte, preds_test), 
                 r2_score(yte, preds_test)]
    }
    df = pd.DataFrame(metrics)
    print(f"Resultados para {model_name}:")
    print(df.to_string(index=False))
    print()

# Baseline mean  
baseline_mean = DummyRegressor(strategy = 'mean')  
baseline_mean.fit(Xtr_s, ytr)  
preds_test = baseline_mean.predict(Xte_s)  
evaluate_model(yte, preds_test, 'Baseline')  

# Linear Regression  
model_linear = LinearRegression()  
model_linear.fit(Xtr_s, ytr)  
preds_test = model_linear.predict(Xte_s)  
evaluate_model(yte, preds_test, 'Linear')  

# Your code here  
knn = KNeighborsRegressor()
knn.fit(Xtr_s, ytr)
y_pred = knn.predict(Xte_s)
evaluate_model(yte, y_pred, 'KNN')

tree = DecisionTreeRegressor()
tree.fit(Xtr_s, ytr)
y_pred = tree.predict(Xte_s)
evaluate_model(yte, y_pred, 'Decision Trees')

svr = SVR(kernel='linear')
svr.fit(Xtr_s, ytr)
y_pred = svr.predict(Xte_s)
evaluate_model(yte, y_pred, 'SVR')
# Out:
# Resultados para Baseline:
# Métrica      TEST
#     MAE  5.881563
#     MSE 52.489406
#      R² -0.007713
#
# Resultados para Linear:
# Métrica     TEST
#     MAE 1.055938
#     MSE 2.297831
#      R² 0.955885
#
# Resultados para KNN:
# Métrica     TEST
#     MAE 0.816886
#     MSE 1.799855
#      R² 0.965446
#
# Resultados para Decision Trees:
# Métrica     TEST
#     MAE 1.109707
#     MSE 3.574710
#      R² 0.931371
#
# Resultados para SVR:
# Métrica     TEST
#     MAE 0.793983
#     MSE 1.787832
#      R² 0.965676

# %% [markdown]
# The results should look something like this:
#
# <center>
#
# | Model                  | MAE Test  | MSE Test  | R² Test  |
# |------------------------|-----------|-----------|----------|
# | *Baseline*             | 5.882     | 52.489    | -0.008   |
# | *Linear*               | 1.056     |  2.298    |  0.956   |
# | *KNN*                  | 0.820     |  1.801    |  0.965   |
# | *Decision Trees*       | 1.110     |  3.575    |  0.931   |
# | *SVR*                  | 0.735     |  1.738    |  0.967   |
#
# </center>

# %% [markdown]
# ### **2.3. Neural Network**
#
# Once we have the datasets and results from the traditional models, we can now create our first neural network from scratch.
#
# The steps to create and train a neural network are as follows:
#
# 1) Create the model architecture.
# 2) Define the optimizer, loss function, and compile the model.
# 3) Train and evaluate the model.
#
# #### **2.3.1. Create Architecture**
#
# The first thing we need to define is its architecture, meaning the number of fully connected layers that make up the network.
#
# <div class="alert alert-block alert-warning">
#     <strong>Note:</strong> As you know, the size of the input and output layers is determined by the problem at hand. In this case, we have 1 input and 1 output.
# </div>
#
# The simplest network in this case would be as follows:

# %%
import os, random  
import numpy as np  
import tensorflow as tf  

from tensorflow.keras.models import Sequential  
from tensorflow.keras.layers import Dense, Input  

# Set the seeds for the libraries to ensure results are reproducible.  
os.environ['PYTHONHASHSEED'] = str(seed)  
random.seed(seed)  
np.random.seed(seed)  
tf.random.set_seed(seed)  

# Define the layers of the model  
model = Sequential()  
model.add(Input(shape = (1,)))  
model.add(Dense(1, name = 'output_layer'))

# %% [markdown]
# The previous code simply creates a `Sequential()` model, meaning a model where layers are added one after the other.
#
# Next, we introduce the following layers into it:
#
# * `Input()`: Input layer. It is not a layer in itself; it simply allows the model to know the size of the inputs.
# * `Dense()`: Fully connected layer ($y=Wx+b$). We specify the size as a required parameter, and `name` is optional.
#
# To view the final architecture of our model, we can execute the `summary()` method, which also provides information about the parameters.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ output_layer (Dense)            │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# It is important to note that, as we mentioned earlier, since `Input()` is not actually a layer, it does not even appear in the summary.
#
# Another relevant piece of information is the number of parameters or weights in the model, i.e., how many $W$ and $b$ it needs to learn during training to correctly transform the input into the output.
#
# In this case, there are only 2: one $w$ and one $b$.
#
# #### **2.3.2. Compile the Model**

# %% [markdown]
# Compiling a model in Keras is an essential step before training it. It serves to configure the learning process, specifying how the model will be optimized and how its performance will be evaluated. Essentially, it defines the following key elements:
#
# *   **Optimizer:** Defines the algorithm that will be used to adjust the model's weights during training, aiming to minimize the loss function. Common examples are `Adam`, `SGD`, `RMSprop`, among others. Each optimizer has its own hyperparameters (such as learning rate) that can be adjusted.
#
# *   **Loss Function:** Measures the difference between the model's predictions and the actual values (labels). The goal of training is to **minimize this loss**. The choice of loss function depends on the type of problem (classification, regression, etc.). Examples: `categorical_crossentropy` (for multiclass classification), `binary_crossentropy` (for binary or multilabel classification), `mean_squared_error` or `mean_absolute_error` (for regression).
#
# Next, we compile the model by specifying the `Adam` optimizer with a `learning_rate = 0.05` and a regression loss function (`mean_absolute_error`).

# %%
from tensorflow.keras.optimizers import Adam

learning_rate = 0.001
optim = Adam(learning_rate = learning_rate)
model.compile(loss = 'mean_absolute_error', optimizer = optim )

# %% [markdown]
# #### **2.3.3. Train and Evaluate**

# %% [markdown]
# The next step is the training and evaluation of the model. In `keras`, training is done through the [`.fit()`](https://keras.io/api/models/model_training_apis/) method, just like in `scikit-learn`.
#
# This method also takes in the training data ($X$ and $Y$) and iteratively adjusts the model's weights (the $W$ and $b$) to minimize the loss function.
#
# Specifically, this method performs the following steps:
#
# 1) **Batch Creation:** Divides the entire training dataset into batches (blocks of examples) and obtains the model's prediction for each batch. Neural networks are designed to work with very large datasets, and often it's not feasible to train with the entire dataset at once, as we did in previous machine learning methods.
# 2) **Calculates the Loss:** Compares the model's predictions $\hat{Y}$ with the actual labels $Y$ and calculates the loss defined during compilation, $MAE$ in this case.
# 3) **Calculates Gradients:** Uses the backpropagation algorithm to compute the gradients of the loss function with respect to the model's weights. The gradients indicate the direction and magnitude of the change needed in the weights to reduce the loss.
#
# <center>
#     <div style="border-radius:5px; padding:10px; background:white; max-width:900px">
#         <img src="https://i.imgur.com/1tscXrJ.png">
#     </div>
# </center>
#
# 4) **Updates Weights:** Adjusts the model's weights using the optimizer based on the calculated gradients. The optimizer determines how the weights should be updated efficiently to minimize the loss.
# 5) **Repeats the Process:** Repeats the above steps for each of the training batches. Once all batches are processed, the entire process can be repeated for a set number of epochs.
#
# <div class="alert alert-block alert-warning">
#     <strong>Note:</strong> An epoch represents a full pass through the entire training dataset.
# </div>
#
# Next, we train the model using the training data:

# %%
# Train the model. The verbose parameter in the train method allows configuring the amount of information displayed in the console during training.
history = model.fit(Xtr_s, ytr, validation_split = 0.2, batch_size = 64, epochs = 200, verbose = 2)
# Out:
# Epoch 1/200
# 13/13 - 0s - 18ms/step - loss: 82.7374 - val_loss: 82.4819
# Epoch 2/200
# 13/13 - 0s - 1ms/step - loss: 82.7243 - val_loss: 82.4689
# Epoch 3/200
# 13/13 - 0s - 1ms/step - loss: 82.7113 - val_loss: 82.4559
# Epoch 4/200
# 13/13 - 0s - 1ms/step - loss: 82.6983 - val_loss: 82.4430
# Epoch 5/200
# 13/13 - 0s - 1ms/step - loss: 82.6853 - val_loss: 82.4300
# Epoch 6/200
# 13/13 - 0s - 1ms/step - loss: 82.6723 - val_loss: 82.4170
# Epoch 7/200
# 13/13 - 0s - 1ms/step - loss: 82.6593 - val_loss: 82.4040
# Epoch 8/200
# 13/13 - 0s - 1ms/step - loss: 82.6462 - val_loss: 82.3911
# Epoch 9/200
# 13/13 - 0s - 1ms/step - loss: 82.6332 - val_loss: 82.3781
# Epoch 10/200
# 13/13 - 0s - 1ms/step - loss: 82.6202 - val_loss: 82.3651
# Epoch 11/200
# 13/13 - 0s - 1ms/step - loss: 82.6072 - val_loss: 82.3521
# Epoch 12/200
# 13/13 - 0s - 1ms/step - loss: 82.5942 - val_loss: 82.3392
# Epoch 13/200
# 13/13 - 0s - 1ms/step - loss: 82.5812 - val_loss: 82.3262
# Epoch 14/200
# 13/13 - 0s - 1ms/step - loss: 82.5682 - val_loss: 82.3132
# Epoch 15/200
# 13/13 - 0s - 1ms/step - loss: 82.5552 - val_loss: 82.3003
# Epoch 16/200
# 13/13 - 0s - 1ms/step - loss: 82.5422 - val_loss: 82.2873
# Epoch 17/200
# 13/13 - 0s - 1ms/step - loss: 82.5292 - val_loss: 82.2743
# Epoch 18/200
# 13/13 - 0s - 1ms/step - loss: 82.5162 - val_loss: 82.2613
# Epoch 19/200
# 13/13 - 0s - 1ms/step - loss: 82.5032 - val_loss: 82.2484
# Epoch 20/200
# 13/13 - 0s - 1ms/step - loss: 82.4902 - val_loss: 82.2354
# Epoch 21/200
# 13/13 - 0s - 1ms/step - loss: 82.4772 - val_loss: 82.2224
# Epoch 22/200
# 13/13 - 0s - 1ms/step - loss: 82.4642 - val_loss: 82.2094
# Epoch 23/200
# 13/13 - 0s - 1ms/step - loss: 82.4512 - val_loss: 82.1965
# Epoch 24/200
# 13/13 - 0s - 1ms/step - loss: 82.4381 - val_loss: 82.1835
# Epoch 25/200
# 13/13 - 0s - 1ms/step - loss: 82.4251 - val_loss: 82.1705
# Epoch 26/200
# 13/13 - 0s - 1ms/step - loss: 82.4121 - val_loss: 82.1576
# Epoch 27/200
# 13/13 - 0s - 1ms/step - loss: 82.3991 - val_loss: 82.1446
# Epoch 28/200
# 13/13 - 0s - 1ms/step - loss: 82.3861 - val_loss: 82.1316
# Epoch 29/200
# 13/13 - 0s - 1ms/step - loss: 82.3731 - val_loss: 82.1186
# Epoch 30/200
# 13/13 - 0s - 1ms/step - loss: 82.3601 - val_loss: 82.1057
# Epoch 31/200
# 13/13 - 0s - 1ms/step - loss: 82.3471 - val_loss: 82.0927
# Epoch 32/200
# 13/13 - 0s - 1ms/step - loss: 82.3341 - val_loss: 82.0797
# Epoch 33/200
# 13/13 - 0s - 1ms/step - loss: 82.3211 - val_loss: 82.0667
# Epoch 34/200
# 13/13 - 0s - 1ms/step - loss: 82.3081 - val_loss: 82.0538
# Epoch 35/200
# 13/13 - 0s - 1ms/step - loss: 82.2951 - val_loss: 82.0408
# Epoch 36/200
# 13/13 - 0s - 1ms/step - loss: 82.2821 - val_loss: 82.0278
# Epoch 37/200
# 13/13 - 0s - 1ms/step - loss: 82.2691 - val_loss: 82.0149
# Epoch 38/200
# 13/13 - 0s - 1ms/step - loss: 82.2561 - val_loss: 82.0019
# Epoch 39/200
# 13/13 - 0s - 1ms/step - loss: 82.2430 - val_loss: 81.9889
# Epoch 40/200
# 13/13 - 0s - 1ms/step - loss: 82.2300 - val_loss: 81.9759
# Epoch 41/200
# 13/13 - 0s - 1ms/step - loss: 82.2170 - val_loss: 81.9630
# Epoch 42/200
# 13/13 - 0s - 1ms/step - loss: 82.2040 - val_loss: 81.9500
# Epoch 43/200
# 13/13 - 0s - 1ms/step - loss: 82.1910 - val_loss: 81.9370
# Epoch 44/200
# 13/13 - 0s - 1ms/step - loss: 82.1780 - val_loss: 81.9240
# Epoch 45/200
# 13/13 - 0s - 1ms/step - loss: 82.1650 - val_loss: 81.9111
# Epoch 46/200
# 13/13 - 0s - 1ms/step - loss: 82.1520 - val_loss: 81.8981
# Epoch 47/200
# 13/13 - 0s - 1ms/step - loss: 82.1390 - val_loss: 81.8851
# Epoch 48/200
# 13/13 - 0s - 1ms/step - loss: 82.1260 - val_loss: 81.8721
# Epoch 49/200
# 13/13 - 0s - 1ms/step - loss: 82.1130 - val_loss: 81.8592
# Epoch 50/200
# 13/13 - 0s - 1ms/step - loss: 82.1000 - val_loss: 81.8462
# Epoch 51/200
# 13/13 - 0s - 1ms/step - loss: 82.0870 - val_loss: 81.8332
# Epoch 52/200
# 13/13 - 0s - 1ms/step - loss: 82.0740 - val_loss: 81.8203
# Epoch 53/200
# 13/13 - 0s - 1ms/step - loss: 82.0610 - val_loss: 81.8073
# Epoch 54/200
# 13/13 - 0s - 1ms/step - loss: 82.0480 - val_loss: 81.7943
# Epoch 55/200
# 13/13 - 0s - 1ms/step - loss: 82.0349 - val_loss: 81.7813
# Epoch 56/200
# 13/13 - 0s - 1ms/step - loss: 82.0219 - val_loss: 81.7684
# Epoch 57/200
# 13/13 - 0s - 1ms/step - loss: 82.0089 - val_loss: 81.7554
# Epoch 58/200
# 13/13 - 0s - 1ms/step - loss: 81.9959 - val_loss: 81.7424
# Epoch 59/200
# 13/13 - 0s - 1ms/step - loss: 81.9829 - val_loss: 81.7294
# Epoch 60/200
# 13/13 - 0s - 1ms/step - loss: 81.9699 - val_loss: 81.7165
# Epoch 61/200
# 13/13 - 0s - 1ms/step - loss: 81.9569 - val_loss: 81.7035
# Epoch 62/200
# 13/13 - 0s - 1ms/step - loss: 81.9439 - val_loss: 81.6905
# Epoch 63/200
# 13/13 - 0s - 1ms/step - loss: 81.9309 - val_loss: 81.6775
# Epoch 64/200
# 13/13 - 0s - 1ms/step - loss: 81.9179 - val_loss: 81.6646
# Epoch 65/200
# 13/13 - 0s - 1ms/step - loss: 81.9049 - val_loss: 81.6516
# Epoch 66/200
# 13/13 - 0s - 1ms/step - loss: 81.8919 - val_loss: 81.6386
# Epoch 67/200
# 13/13 - 0s - 1ms/step - loss: 81.8789 - val_loss: 81.6256
# Epoch 68/200
# 13/13 - 0s - 1ms/step - loss: 81.8659 - val_loss: 81.6127
# Epoch 69/200
# 13/13 - 0s - 1ms/step - loss: 81.8529 - val_loss: 81.5997
# Epoch 70/200
# 13/13 - 0s - 1ms/step - loss: 81.8399 - val_loss: 81.5867
# Epoch 71/200
# 13/13 - 0s - 1ms/step - loss: 81.8268 - val_loss: 81.5738
# Epoch 72/200
# 13/13 - 0s - 1ms/step - loss: 81.8138 - val_loss: 81.5608
# Epoch 73/200
# 13/13 - 0s - 1ms/step - loss: 81.8008 - val_loss: 81.5478
# Epoch 74/200
# 13/13 - 0s - 1ms/step - loss: 81.7878 - val_loss: 81.5348
# Epoch 75/200
# 13/13 - 0s - 1ms/step - loss: 81.7748 - val_loss: 81.5219
# Epoch 76/200
# 13/13 - 0s - 1ms/step - loss: 81.7618 - val_loss: 81.5089
# Epoch 77/200
# 13/13 - 0s - 1ms/step - loss: 81.7488 - val_loss: 81.4959
# Epoch 78/200
# 13/13 - 0s - 1ms/step - loss: 81.7358 - val_loss: 81.4829
# Epoch 79/200
# 13/13 - 0s - 1ms/step - loss: 81.7228 - val_loss: 81.4700
# Epoch 80/200
# 13/13 - 0s - 1ms/step - loss: 81.7098 - val_loss: 81.4570
# Epoch 81/200
# 13/13 - 0s - 1ms/step - loss: 81.6968 - val_loss: 81.4440
# Epoch 82/200
# 13/13 - 0s - 1ms/step - loss: 81.6838 - val_loss: 81.4311
# Epoch 83/200
# 13/13 - 0s - 1ms/step - loss: 81.6708 - val_loss: 81.4181
# Epoch 84/200
# 13/13 - 0s - 1ms/step - loss: 81.6578 - val_loss: 81.4051
# Epoch 85/200
# 13/13 - 0s - 1ms/step - loss: 81.6448 - val_loss: 81.3921
# Epoch 86/200
# 13/13 - 0s - 1ms/step - loss: 81.6317 - val_loss: 81.3792
# Epoch 87/200
# 13/13 - 0s - 1ms/step - loss: 81.6187 - val_loss: 81.3662
# Epoch 88/200
# 13/13 - 0s - 1ms/step - loss: 81.6057 - val_loss: 81.3532
# Epoch 89/200
# 13/13 - 0s - 1ms/step - loss: 81.5927 - val_loss: 81.3402
# Epoch 90/200
# 13/13 - 0s - 1ms/step - loss: 81.5797 - val_loss: 81.3273
# Epoch 91/200
# 13/13 - 0s - 1ms/step - loss: 81.5667 - val_loss: 81.3143
# Epoch 92/200
# 13/13 - 0s - 1ms/step - loss: 81.5537 - val_loss: 81.3013
# Epoch 93/200
# 13/13 - 0s - 1ms/step - loss: 81.5407 - val_loss: 81.2883
# Epoch 94/200
# 13/13 - 0s - 1ms/step - loss: 81.5277 - val_loss: 81.2754
# Epoch 95/200
# 13/13 - 0s - 1ms/step - loss: 81.5147 - val_loss: 81.2624
# Epoch 96/200
# 13/13 - 0s - 1ms/step - loss: 81.5017 - val_loss: 81.2494
# Epoch 97/200
# 13/13 - 0s - 1ms/step - loss: 81.4887 - val_loss: 81.2364
# Epoch 98/200
# 13/13 - 0s - 1ms/step - loss: 81.4756 - val_loss: 81.2235
# Epoch 99/200
# 13/13 - 0s - 1ms/step - loss: 81.4626 - val_loss: 81.2105
# Epoch 100/200
# 13/13 - 0s - 1ms/step - loss: 81.4496 - val_loss: 81.1975
# Epoch 101/200
# 13/13 - 0s - 1ms/step - loss: 81.4366 - val_loss: 81.1845
# Epoch 102/200
# 13/13 - 0s - 1ms/step - loss: 81.4236 - val_loss: 81.1716
# Epoch 103/200
# 13/13 - 0s - 1ms/step - loss: 81.4106 - val_loss: 81.1586
# Epoch 104/200
# 13/13 - 0s - 1ms/step - loss: 81.3976 - val_loss: 81.1456
# Epoch 105/200
# 13/13 - 0s - 1ms/step - loss: 81.3846 - val_loss: 81.1326
# Epoch 106/200
# 13/13 - 0s - 1ms/step - loss: 81.3716 - val_loss: 81.1197
# Epoch 107/200
# 13/13 - 0s - 1ms/step - loss: 81.3586 - val_loss: 81.1067
# Epoch 108/200
# 13/13 - 0s - 1ms/step - loss: 81.3456 - val_loss: 81.0937
# Epoch 109/200
# 13/13 - 0s - 1ms/step - loss: 81.3326 - val_loss: 81.0808
# Epoch 110/200
# 13/13 - 0s - 1ms/step - loss: 81.3196 - val_loss: 81.0678
# Epoch 111/200
# 13/13 - 0s - 1ms/step - loss: 81.3066 - val_loss: 81.0548
# Epoch 112/200
# 13/13 - 0s - 1ms/step - loss: 81.2935 - val_loss: 81.0418
# Epoch 113/200
# 13/13 - 0s - 1ms/step - loss: 81.2805 - val_loss: 81.0289
# Epoch 114/200
# 13/13 - 0s - 1ms/step - loss: 81.2675 - val_loss: 81.0159
# Epoch 115/200
# 13/13 - 0s - 1ms/step - loss: 81.2545 - val_loss: 81.0029
# Epoch 116/200
# 13/13 - 0s - 1ms/step - loss: 81.2415 - val_loss: 80.9899
# Epoch 117/200
# 13/13 - 0s - 1ms/step - loss: 81.2285 - val_loss: 80.9770
# Epoch 118/200
# 13/13 - 0s - 1ms/step - loss: 81.2155 - val_loss: 80.9640
# Epoch 119/200
# 13/13 - 0s - 1ms/step - loss: 81.2025 - val_loss: 80.9510
# Epoch 120/200
# 13/13 - 0s - 1ms/step - loss: 81.1895 - val_loss: 80.9380
# Epoch 121/200
# 13/13 - 0s - 1ms/step - loss: 81.1765 - val_loss: 80.9251
# Epoch 122/200
# 13/13 - 0s - 1ms/step - loss: 81.1635 - val_loss: 80.9121
# Epoch 123/200
# 13/13 - 0s - 1ms/step - loss: 81.1505 - val_loss: 80.8991
# Epoch 124/200
# 13/13 - 0s - 1ms/step - loss: 81.1375 - val_loss: 80.8861
# Epoch 125/200
# 13/13 - 0s - 1ms/step - loss: 81.1245 - val_loss: 80.8732
# Epoch 126/200
# 13/13 - 0s - 1ms/step - loss: 81.1114 - val_loss: 80.8602
# Epoch 127/200
# 13/13 - 0s - 1ms/step - loss: 81.0984 - val_loss: 80.8472
# Epoch 128/200
# 13/13 - 0s - 1ms/step - loss: 81.0854 - val_loss: 80.8343
# Epoch 129/200
# 13/13 - 0s - 1ms/step - loss: 81.0724 - val_loss: 80.8213
# Epoch 130/200
# 13/13 - 0s - 1ms/step - loss: 81.0594 - val_loss: 80.8083
# Epoch 131/200
# 13/13 - 0s - 1ms/step - loss: 81.0464 - val_loss: 80.7953
# Epoch 132/200
# 13/13 - 0s - 1ms/step - loss: 81.0334 - val_loss: 80.7823
# Epoch 133/200
# 13/13 - 0s - 1ms/step - loss: 81.0204 - val_loss: 80.7694
# Epoch 134/200
# 13/13 - 0s - 1ms/step - loss: 81.0074 - val_loss: 80.7564
# Epoch 135/200
# 13/13 - 0s - 1ms/step - loss: 80.9944 - val_loss: 80.7434
# Epoch 136/200
# 13/13 - 0s - 1ms/step - loss: 80.9814 - val_loss: 80.7305
# Epoch 137/200
# 13/13 - 0s - 1ms/step - loss: 80.9684 - val_loss: 80.7175
# Epoch 138/200
# 13/13 - 0s - 1ms/step - loss: 80.9554 - val_loss: 80.7045
# Epoch 139/200
# 13/13 - 0s - 1ms/step - loss: 80.9423 - val_loss: 80.6915
# Epoch 140/200
# 13/13 - 0s - 1ms/step - loss: 80.9293 - val_loss: 80.6786
# Epoch 141/200
# 13/13 - 0s - 1ms/step - loss: 80.9163 - val_loss: 80.6656
# Epoch 142/200
# 13/13 - 0s - 1ms/step - loss: 80.9033 - val_loss: 80.6526
# Epoch 143/200
# 13/13 - 0s - 1ms/step - loss: 80.8903 - val_loss: 80.6396
# Epoch 144/200
# 13/13 - 0s - 1ms/step - loss: 80.8773 - val_loss: 80.6267
# Epoch 145/200
# 13/13 - 0s - 1ms/step - loss: 80.8643 - val_loss: 80.6137
# Epoch 146/200
# 13/13 - 0s - 1ms/step - loss: 80.8513 - val_loss: 80.6007
# Epoch 147/200
# 13/13 - 0s - 2ms/step - loss: 80.8383 - val_loss: 80.5877
# Epoch 148/200
# 13/13 - 0s - 2ms/step - loss: 80.8253 - val_loss: 80.5748
# Epoch 149/200
# 13/13 - 0s - 1ms/step - loss: 80.8123 - val_loss: 80.5618
# Epoch 150/200
# 13/13 - 0s - 1ms/step - loss: 80.7993 - val_loss: 80.5488
# Epoch 151/200
# 13/13 - 0s - 1ms/step - loss: 80.7863 - val_loss: 80.5359
# Epoch 152/200
# 13/13 - 0s - 1ms/step - loss: 80.7733 - val_loss: 80.5229
# Epoch 153/200
# 13/13 - 0s - 1ms/step - loss: 80.7602 - val_loss: 80.5099
# Epoch 154/200
# 13/13 - 0s - 1ms/step - loss: 80.7472 - val_loss: 80.4969
# Epoch 155/200
# 13/13 - 0s - 1ms/step - loss: 80.7342 - val_loss: 80.4839
# Epoch 156/200
# 13/13 - 0s - 1ms/step - loss: 80.7212 - val_loss: 80.4710
# Epoch 157/200
# 13/13 - 0s - 1ms/step - loss: 80.7082 - val_loss: 80.4580
# Epoch 158/200
# 13/13 - 0s - 1ms/step - loss: 80.6952 - val_loss: 80.4450
# Epoch 159/200
# 13/13 - 0s - 1ms/step - loss: 80.6822 - val_loss: 80.4321
# Epoch 160/200
# 13/13 - 0s - 1ms/step - loss: 80.6692 - val_loss: 80.4191
# Epoch 161/200
# 13/13 - 0s - 1ms/step - loss: 80.6562 - val_loss: 80.4061
# Epoch 162/200
# 13/13 - 0s - 1ms/step - loss: 80.6432 - val_loss: 80.3931
# Epoch 163/200
# 13/13 - 0s - 1ms/step - loss: 80.6302 - val_loss: 80.3802
# Epoch 164/200
# 13/13 - 0s - 1ms/step - loss: 80.6172 - val_loss: 80.3672
# Epoch 165/200
# 13/13 - 0s - 1ms/step - loss: 80.6042 - val_loss: 80.3542
# Epoch 166/200
# 13/13 - 0s - 1ms/step - loss: 80.5912 - val_loss: 80.3413
# Epoch 167/200
# 13/13 - 0s - 1ms/step - loss: 80.5782 - val_loss: 80.3283
# Epoch 168/200
# 13/13 - 0s - 1ms/step - loss: 80.5652 - val_loss: 80.3153
# Epoch 169/200
# 13/13 - 0s - 1ms/step - loss: 80.5521 - val_loss: 80.3023
# Epoch 170/200
# 13/13 - 0s - 1ms/step - loss: 80.5391 - val_loss: 80.2894
# Epoch 171/200
# 13/13 - 0s - 1ms/step - loss: 80.5261 - val_loss: 80.2764
# Epoch 172/200
# 13/13 - 0s - 1ms/step - loss: 80.5131 - val_loss: 80.2634
# Epoch 173/200
# 13/13 - 0s - 1ms/step - loss: 80.5001 - val_loss: 80.2505
# Epoch 174/200
# 13/13 - 0s - 1ms/step - loss: 80.4871 - val_loss: 80.2375
# Epoch 175/200
# 13/13 - 0s - 1ms/step - loss: 80.4741 - val_loss: 80.2245
# Epoch 176/200
# 13/13 - 0s - 1ms/step - loss: 80.4611 - val_loss: 80.2115
# Epoch 177/200
# 13/13 - 0s - 1ms/step - loss: 80.4481 - val_loss: 80.1986
# Epoch 178/200
# 13/13 - 0s - 1ms/step - loss: 80.4351 - val_loss: 80.1856
# Epoch 179/200
# 13/13 - 0s - 1ms/step - loss: 80.4221 - val_loss: 80.1726
# Epoch 180/200
# 13/13 - 0s - 1ms/step - loss: 80.4091 - val_loss: 80.1596
# Epoch 181/200
# 13/13 - 0s - 1ms/step - loss: 80.3961 - val_loss: 80.1467
# Epoch 182/200
# 13/13 - 0s - 1ms/step - loss: 80.3831 - val_loss: 80.1337
# Epoch 183/200
# 13/13 - 0s - 1ms/step - loss: 80.3701 - val_loss: 80.1207
# Epoch 184/200
# 13/13 - 0s - 1ms/step - loss: 80.3571 - val_loss: 80.1078
# Epoch 185/200
# 13/13 - 0s - 1ms/step - loss: 80.3441 - val_loss: 80.0948
# Epoch 186/200
# 13/13 - 0s - 1ms/step - loss: 80.3311 - val_loss: 80.0818
# Epoch 187/200
# 13/13 - 0s - 1ms/step - loss: 80.3181 - val_loss: 80.0688
# Epoch 188/200
# 13/13 - 0s - 1ms/step - loss: 80.3050 - val_loss: 80.0559
# Epoch 189/200
# 13/13 - 0s - 1ms/step - loss: 80.2920 - val_loss: 80.0429
# Epoch 190/200
# 13/13 - 0s - 1ms/step - loss: 80.2790 - val_loss: 80.0299
# Epoch 191/200
# 13/13 - 0s - 1ms/step - loss: 80.2660 - val_loss: 80.0169
# Epoch 192/200
# 13/13 - 0s - 1ms/step - loss: 80.2530 - val_loss: 80.0040
# Epoch 193/200
# 13/13 - 0s - 1ms/step - loss: 80.2400 - val_loss: 79.9910
# Epoch 194/200
# 13/13 - 0s - 1ms/step - loss: 80.2270 - val_loss: 79.9780
# Epoch 195/200
# 13/13 - 0s - 1ms/step - loss: 80.2140 - val_loss: 79.9651
# Epoch 196/200
# 13/13 - 0s - 1ms/step - loss: 80.2010 - val_loss: 79.9521
# Epoch 197/200
# 13/13 - 0s - 1ms/step - loss: 80.1880 - val_loss: 79.9391
# Epoch 198/200
# 13/13 - 0s - 1ms/step - loss: 80.1750 - val_loss: 79.9261
# Epoch 199/200
# 13/13 - 0s - 1ms/step - loss: 80.1620 - val_loss: 79.9132
# Epoch 200/200
# 13/13 - 0s - 1ms/step - loss: 80.1490 - val_loss: 79.9002

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <strong>Note:</strong> Every time you run the previous block, <strong>training will continue</strong> from where it left off. To train the model from scratch, you would need to recreate and recompile it.
# </div>
#
# As you can see, there is an argument in the `fit` method that we haven't discussed: `validation_split`.
#
# This argument reserves a fraction of the training data to use it as a validation set; in other words, it separates 20% of the examples from the training set (in this case, since `validation_split=0.2`).
#
# So now, our dataset is split into three distinct blocks: Train, Validation, and Test. This approach is also known as **metavalidation**.
#
# ##### **Metavalidation**
#
# Until now, to validate our model, we have used **simple validation** or hold-out, meaning we split it into: Train and Test.
#
# This approach is very valid for cases where the models we want to evaluate do not have **hyperparameters**, like linear regression.
#
# <div class="alert alert-block alert-warning">
#     <strong>Note:</strong> The validation set is used to adjust the model's hyperparameters. <hr>
#     Remember that a hyperparameter is any value we can set when creating a model, for example, the K in KNN.
# </div>
#
# Neural networks have multiple hyperparameters to adjust such as `learning rate`, `batch size`, `epochs`, `number of layers`, `number of neurons`, etc. Therefore, a validation set is necessary.
#
# Now, the training process changes slightly: Based on the training data, the model calculates the loss and updates the weights accordingly, then *calculates the loss on the validation set* **but does not update the weights with this data**.
#
# This allows:
#
# * **Monitor overfitting:** If performance on the training set keeps improving but performance on the validation set stagnates or worsens, this indicates that the model is starting to overfit the training data and losing its ability to generalize to new data.
# * **Adjust hyperparameters:** We adjust the values of hyperparameters to select the configuration that produces the best performance on the validation data.
#
# <hr>
#
# ##### **Why don't we use Test directly to adjust the hyperparameters?**
#
# Imagine you want to bake the perfect cake to take to a baking contest.
#
# * **Training set (train):** These are all the tests you do at home with different recipes, temperatures, and times. Here, you try many combinations to learn how each change affects the outcome.
#
# * **Validation set (val):** Every time you bake a cake at home, you let your friends or family try it. They tell you if it's too dry, too sweet, if the texture is good... With that feedback, you adjust the recipe: more sugar? less time in the oven? This is the process of adjusting hyperparameters.
#
# * **Test set (test):** This is the contest jury. You've never let them taste any of your cakes. They will evaluate whether, beyond your adjustments, your recipe truly works.
#
# **Where's the trap?**
#
# If, before the contest, you have the jury taste several cakes and tell you what to change, when you go to the contest, you'll already know what they like.
# You won't be testing if your recipe is good in general, but rather you'll have made a cake tailored to them.
#
# <hr>
#
# In summary:
# * **Train:** The dataset used to train the model, adjusting its weights to minimize the loss function.
# * **Validation:** The dataset used to monitor overfitting and optimize the model's hyperparameters, **but not the weights**.
# * **Test:** The dataset used to evaluate the final performance of the model trained with the optimal hyperparameters and data that was not used previously (neither for training nor for hyperparameter adjustment).
#
# The `fit()` method returns an object that stores the entire history of the model's training across the epochs. In this case, we store the result in `history`.
#
# Now let's create a function to visualize the evolution of the training and validation losses:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

def plot_loss_history(history):
    # Extract history data
    loss = history.history['loss']
    val_loss = history.history.get('val_loss', []) # Empty by default
    epochs = range(1, len(loss) + 1)
    # Construct the DataFrame
    data = pd.DataFrame({ 'Epoch': epochs, 'Loss': loss, 'Type': 'Train' })
    # If validation exist, use the data
    if val_loss:
        val_df = pd.DataFrame({ 'Epoch': epochs, 'Loss': val_loss, 'Type': 'Validation' })
        data = pd.concat([data, val_df], ignore_index=True)
    # Create the graph
    plt.figure(figsize=(10, 5))
    sns.lineplot(data=data, x="Epoch", y="Loss", hue="Type")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title("Evolución de la Pérdida durante el Entrenamiento")
    plt.grid(True, linestyle='--', alpha=0.7)
    # Show legend only if needed
    if val_loss: plt.legend(title="Conjunto")
    else: plt.legend().remove() # Avoid empty legends
    plt.show()

# Call the function (after training the model)
plot_loss_history(history)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Exercise:</b> For simplicity, let's combine the creation and compilation of the network into one function. Complete the following code and retrain the network from scratch.
# </div>

# %%
def neural_network_one(learning_rate):
    # Create and compile the model
    model = Sequential()  
    model.add(Input(shape = (1,)))  
    model.add(Dense(1, name = 'output_layer'))

    optim = Adam(learning_rate = learning_rate)
    model.compile(loss = 'mean_absolute_error', optimizer = optim)
    return model

# Create the network from scratch
model_1 = neural_network_one(learning_rate = 0.1)

# Train
# Your code here
history = model_1.fit(Xtr_s, ytr, validation_split = 0.2, batch_size = 64, epochs = 200, verbose = 2)
# Visualize training
# Your code here
# Call the function (after training the model)
plot_loss_history(history)
# Out:
# Epoch 1/200
# 13/13 - 0s - 16ms/step - loss: 82.1588 - val_loss: 81.2655
# Epoch 2/200
# 13/13 - 0s - 1ms/step - loss: 80.8498 - val_loss: 79.9669
# Epoch 3/200
# 13/13 - 0s - 1ms/step - loss: 79.5485 - val_loss: 78.6693
# Epoch 4/200
# 13/13 - 0s - 1ms/step - loss: 78.2477 - val_loss: 77.3719
# Epoch 5/200
# 13/13 - 0s - 1ms/step - loss: 76.9470 - val_loss: 76.0745
# Epoch 6/200
# 13/13 - 0s - 1ms/step - loss: 75.6463 - val_loss: 74.7772
# Epoch 7/200
# 13/13 - 0s - 1ms/step - loss: 74.3457 - val_loss: 73.4798
# Epoch 8/200
# 13/13 - 0s - 1ms/step - loss: 73.0450 - val_loss: 72.1824
# Epoch 9/200
# 13/13 - 0s - 1ms/step - loss: 71.7444 - val_loss: 70.8851
# Epoch 10/200
# 13/13 - 0s - 1ms/step - loss: 70.4437 - val_loss: 69.5878
# Epoch 11/200
# 13/13 - 0s - 1ms/step - loss: 69.1431 - val_loss: 68.2904
# Epoch 12/200
# 13/13 - 0s - 1ms/step - loss: 67.8424 - val_loss: 66.9931
# Epoch 13/200
# 13/13 - 0s - 1ms/step - loss: 66.5418 - val_loss: 65.6957
# Epoch 14/200
# 13/13 - 0s - 1ms/step - loss: 65.2411 - val_loss: 64.3984
# Epoch 15/200
# 13/13 - 0s - 1ms/step - loss: 63.9405 - val_loss: 63.1011
# Epoch 16/200
# 13/13 - 0s - 1ms/step - loss: 62.6398 - val_loss: 61.8037
# Epoch 17/200
# 13/13 - 0s - 1ms/step - loss: 61.3392 - val_loss: 60.5064
# Epoch 18/200
# 13/13 - 0s - 1ms/step - loss: 60.0385 - val_loss: 59.2091
# Epoch 19/200
# 13/13 - 0s - 1ms/step - loss: 58.7379 - val_loss: 57.9118
# Epoch 20/200
# 13/13 - 0s - 1ms/step - loss: 57.4373 - val_loss: 56.6144
# Epoch 21/200
# 13/13 - 0s - 1ms/step - loss: 56.1366 - val_loss: 55.3171
# Epoch 22/200
# 13/13 - 0s - 1ms/step - loss: 54.8360 - val_loss: 54.0198
# Epoch 23/200
# 13/13 - 0s - 1ms/step - loss: 53.5353 - val_loss: 52.7225
# Epoch 24/200
# 13/13 - 0s - 1ms/step - loss: 52.2347 - val_loss: 51.4252
# Epoch 25/200
# 13/13 - 0s - 1ms/step - loss: 50.9340 - val_loss: 50.1278
# Epoch 26/200
# 13/13 - 0s - 1ms/step - loss: 49.6334 - val_loss: 48.8305
# Epoch 27/200
# 13/13 - 0s - 1ms/step - loss: 48.3327 - val_loss: 47.5332
# Epoch 28/200
# 13/13 - 0s - 1ms/step - loss: 47.0321 - val_loss: 46.2359
# Epoch 29/200
# 13/13 - 0s - 1ms/step - loss: 45.7314 - val_loss: 44.9385
# Epoch 30/200
# 13/13 - 0s - 1ms/step - loss: 44.4308 - val_loss: 43.6412
# Epoch 31/200
# 13/13 - 0s - 1ms/step - loss: 43.1301 - val_loss: 42.3439
# Epoch 32/200
# 13/13 - 0s - 1ms/step - loss: 41.8295 - val_loss: 41.0466
# Epoch 33/200
# 13/13 - 0s - 1ms/step - loss: 40.5288 - val_loss: 39.7493
# Epoch 34/200
# 13/13 - 0s - 1ms/step - loss: 39.2282 - val_loss: 38.4519
# Epoch 35/200
# 13/13 - 0s - 1ms/step - loss: 37.9276 - val_loss: 37.1546
# Epoch 36/200
# 13/13 - 0s - 1ms/step - loss: 36.6269 - val_loss: 35.8573
# Epoch 37/200
# 13/13 - 0s - 1ms/step - loss: 35.3263 - val_loss: 34.5600
# Epoch 38/200
# 13/13 - 0s - 1ms/step - loss: 34.0256 - val_loss: 33.2626
# Epoch 39/200
# 13/13 - 0s - 1ms/step - loss: 32.7250 - val_loss: 31.9653
# Epoch 40/200
# 13/13 - 0s - 1ms/step - loss: 31.4243 - val_loss: 30.6680
# Epoch 41/200
# 13/13 - 0s - 1ms/step - loss: 30.1237 - val_loss: 29.3707
# Epoch 42/200
# 13/13 - 0s - 1ms/step - loss: 28.8230 - val_loss: 28.0734
# Epoch 43/200
# 13/13 - 0s - 1ms/step - loss: 27.5224 - val_loss: 26.7760
# Epoch 44/200
# 13/13 - 0s - 1ms/step - loss: 26.2217 - val_loss: 25.4787
# Epoch 45/200
# 13/13 - 0s - 1ms/step - loss: 24.9211 - val_loss: 24.1814
# Epoch 46/200
# 13/13 - 0s - 1ms/step - loss: 23.6204 - val_loss: 22.8841
# Epoch 47/200
# 13/13 - 0s - 1ms/step - loss: 22.3198 - val_loss: 21.5868
# Epoch 48/200
# 13/13 - 0s - 1ms/step - loss: 21.0191 - val_loss: 20.2894
# Epoch 49/200
# 13/13 - 0s - 1ms/step - loss: 19.7185 - val_loss: 18.9921
# Epoch 50/200
# 13/13 - 0s - 1ms/step - loss: 18.4178 - val_loss: 17.6948
# Epoch 51/200
# 13/13 - 0s - 1ms/step - loss: 17.1172 - val_loss: 16.3975
# Epoch 52/200
# 13/13 - 0s - 1ms/step - loss: 15.8165 - val_loss: 15.1002
# Epoch 53/200
# 13/13 - 0s - 1ms/step - loss: 14.5159 - val_loss: 13.8029
# Epoch 54/200
# 13/13 - 0s - 1ms/step - loss: 13.2152 - val_loss: 12.5055
# Epoch 55/200
# 13/13 - 0s - 1ms/step - loss: 11.9146 - val_loss: 11.2082
# Epoch 56/200
# 13/13 - 0s - 1ms/step - loss: 10.6163 - val_loss: 9.9298
# Epoch 57/200
# 13/13 - 0s - 1ms/step - loss: 9.3697 - val_loss: 8.7819
# Epoch 58/200
# 13/13 - 0s - 1ms/step - loss: 8.3288 - val_loss: 7.7119
# Epoch 59/200
# 13/13 - 0s - 1ms/step - loss: 7.3132 - val_loss: 6.6028
# Epoch 60/200
# 13/13 - 0s - 1ms/step - loss: 6.2834 - val_loss: 5.5130
# Epoch 61/200
# 13/13 - 0s - 1ms/step - loss: 5.2559 - val_loss: 4.4395
# Epoch 62/200
# 13/13 - 0s - 1ms/step - loss: 4.2411 - val_loss: 3.3707
# Epoch 63/200
# 13/13 - 0s - 1ms/step - loss: 3.2415 - val_loss: 2.4753
# Epoch 64/200
# 13/13 - 0s - 1ms/step - loss: 2.2870 - val_loss: 1.7075
# Epoch 65/200
# 13/13 - 0s - 1ms/step - loss: 1.4579 - val_loss: 1.2172
# Epoch 66/200
# 13/13 - 0s - 1ms/step - loss: 0.9225 - val_loss: 1.1578
# Epoch 67/200
# 13/13 - 0s - 1ms/step - loss: 0.8490 - val_loss: 1.1851
# Epoch 68/200
# 13/13 - 0s - 1ms/step - loss: 0.8501 - val_loss: 1.1707
# Epoch 69/200
# 13/13 - 0s - 1ms/step - loss: 0.8437 - val_loss: 1.1469
# Epoch 70/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1440
# Epoch 71/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1476
# Epoch 72/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1482
# Epoch 73/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1478
# Epoch 74/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1471
# Epoch 75/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1483
# Epoch 76/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1482
# Epoch 77/200
# 13/13 - 0s - 1ms/step - loss: 0.8418 - val_loss: 1.1492
# Epoch 78/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1476
# Epoch 79/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1484
# Epoch 80/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1466
# Epoch 81/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1473
# Epoch 82/200
# 13/13 - 0s - 1ms/step - loss: 0.8418 - val_loss: 1.1479
# Epoch 83/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1478
# Epoch 84/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1472
# Epoch 85/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1485
# Epoch 86/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1483
# Epoch 87/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1494
# Epoch 88/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1477
# Epoch 89/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1467
# Epoch 90/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1478
# Epoch 91/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1478
# Epoch 92/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1472
# Epoch 93/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1481
# Epoch 94/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1486
# Epoch 95/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1483
# Epoch 96/200
# 13/13 - 0s - 2ms/step - loss: 0.8420 - val_loss: 1.1476
# Epoch 97/200
# 13/13 - 0s - 2ms/step - loss: 0.8419 - val_loss: 1.1484
# Epoch 98/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1484
# Epoch 99/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1465
# Epoch 100/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1476
# Epoch 101/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1476
# Epoch 102/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1486
# Epoch 103/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1469
# Epoch 104/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1481
# Epoch 105/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1480
# Epoch 106/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1472
# Epoch 107/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1486
# Epoch 108/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1486
# Epoch 109/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1479
# Epoch 110/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1488
# Epoch 111/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1470
# Epoch 112/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1481
# Epoch 113/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1480
# Epoch 114/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1472
# Epoch 115/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1481
# Epoch 116/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1481
# Epoch 117/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1485
# Epoch 118/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1481
# Epoch 119/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1473
# Epoch 120/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1488
# Epoch 121/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1488
# Epoch 122/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1480
# Epoch 123/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1490
# Epoch 124/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1470
# Epoch 125/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1482
# Epoch 126/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1481
# Epoch 127/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1473
# Epoch 128/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1482
# Epoch 129/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1482
# Epoch 130/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1486
# Epoch 131/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1483
# Epoch 132/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1473
# Epoch 133/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1490
# Epoch 134/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1489
# Epoch 135/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1481
# Epoch 136/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1492
# Epoch 137/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1471
# Epoch 138/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1484
# Epoch 139/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1482
# Epoch 140/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1475
# Epoch 141/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1492
# Epoch 142/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1491
# Epoch 143/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1481
# Epoch 144/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1471
# Epoch 145/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1487
# Epoch 146/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1487
# Epoch 147/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1478
# Epoch 148/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1489
# Epoch 149/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1467
# Epoch 150/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1481
# Epoch 151/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1480
# Epoch 152/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1494
# Epoch 153/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1471
# Epoch 154/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1486
# Epoch 155/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1484
# Epoch 156/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1476
# Epoch 157/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1487
# Epoch 158/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1466
# Epoch 159/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1480
# Epoch 160/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1480
# Epoch 161/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1493
# Epoch 162/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1470
# Epoch 163/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1485
# Epoch 164/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1483
# Epoch 165/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1475
# Epoch 166/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1493
# Epoch 167/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1493
# Epoch 168/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1482
# Epoch 169/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1493
# Epoch 170/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1468
# Epoch 171/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1483
# Epoch 172/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1481
# Epoch 173/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1474
# Epoch 174/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1485
# Epoch 175/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1494
# Epoch 176/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1489
# Epoch 177/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1477
# Epoch 178/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1490
# Epoch 179/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1490
# Epoch 180/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1463
# Epoch 181/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1477
# Epoch 182/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1502
# Epoch 183/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1479
# Epoch 184/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1498
# Epoch 185/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1487
# Epoch 186/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1485
# Epoch 187/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1479
# Epoch 188/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1470
# Epoch 189/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1486
# Epoch 190/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1488
# Epoch 191/200
# 13/13 - 0s - 1ms/step - loss: 0.8424 - val_loss: 1.1478
# Epoch 192/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1489
# Epoch 193/200
# 13/13 - 0s - 1ms/step - loss: 0.8424 - val_loss: 1.1465
# Epoch 194/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1477
# Epoch 195/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1480
# Epoch 196/200
# 13/13 - 0s - 1ms/step - loss: 0.8424 - val_loss: 1.1471
# Epoch 197/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1491
# Epoch 198/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1488
# Epoch 199/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1480
# Epoch 200/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1493

# %% [markdown]
# ##### **Hyperparameter Tuning**
#
# Once everything is combined into a single code block, we can move on to the hyperparameter tuning part.
#
# There are many things we can adjust (`batch size`, `epochs`, `learning rate`, ...) but we will focus on the `learning rate`.
#
# <div class="alert alert-block alert-info">
#     <b>Exercise:</b> Record the results of the last epoch of the previous model in the following table and perform the necessary experiments to complete the rest of the rows.
# </div>
#
# <center>
#
# | Model                    | MAE Train  | MAE Val |
# |---------------------------|------------|---------|
# | *Neural Network (lr=0.001)* | 80.1451 | 79.9158 |
# | *Neural Network (lr=0.05)*  | 0.8417  | 1.1478  |
# | *Neural Network (lr=0.1)*   | 0.8423  | 0.1488  |
#
# <center>

# %%
# Your code here

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Exercise:</b> Train the final model with the best <code>learning_rate</code> and evaluate on test using the <code>.predict()</code> method and the <code>evaluate_model()</code> function created previously.
#     <hr>
#     Add the results to the table.
# </div>
#
# <center>
#
# | Model                   | MAE Test  | MSE Test  | R² Test  |
# |-------------------------|-----------|-----------|----------|
# | *Baseline*              | 5.882     | 52.489    | -0.008   |
# | *Linear*                | 1.056     |  2.298    |  0.956   |
# | *KNN*                   | 0.820     |  1.801    |  0.965   |
# | *Decision Trees*        | 1.110     |  3.575    |  0.931   |
# | *SVR*                   | 0.735     |  1.738    |  0.967   |
# | *Neural Network Linear* | 0.794     |  1.782    |  0.966   |
#
# </center>

# %%
model_1 = neural_network_one(learning_rate = 0.1)
history = model_1.fit(Xtr_s, ytr, validation_split = 0.2, batch_size = 64, epochs = 200, verbose = 2)
plot_loss_history(history)
y_pred = model_1.predict(Xte_s)
evaluate_model(yte, y_pred, 'NNL')
# Out:
# Epoch 1/200
# 13/13 - 0s - 21ms/step - loss: 82.1577 - val_loss: 81.2699
# Epoch 2/200
# 13/13 - 0s - 2ms/step - loss: 80.8487 - val_loss: 79.9713
# Epoch 3/200
# 13/13 - 0s - 1ms/step - loss: 79.5473 - val_loss: 78.6737
# Epoch 4/200
# 13/13 - 0s - 1ms/step - loss: 78.2466 - val_loss: 77.3763
# Epoch 5/200
# 13/13 - 0s - 1ms/step - loss: 76.9459 - val_loss: 76.0789
# Epoch 6/200
# 13/13 - 0s - 1ms/step - loss: 75.6452 - val_loss: 74.7815
# Epoch 7/200
# 13/13 - 0s - 1ms/step - loss: 74.3446 - val_loss: 73.4842
# Epoch 8/200
# 13/13 - 0s - 1ms/step - loss: 73.0439 - val_loss: 72.1868
# Epoch 9/200
# 13/13 - 0s - 1ms/step - loss: 71.7433 - val_loss: 70.8895
# Epoch 10/200
# 13/13 - 0s - 1ms/step - loss: 70.4426 - val_loss: 69.5922
# Epoch 11/200
# 13/13 - 0s - 1ms/step - loss: 69.1420 - val_loss: 68.2948
# Epoch 12/200
# 13/13 - 0s - 1ms/step - loss: 67.8413 - val_loss: 66.9975
# Epoch 13/200
# 13/13 - 0s - 1ms/step - loss: 66.5407 - val_loss: 65.7001
# Epoch 14/200
# 13/13 - 0s - 1ms/step - loss: 65.2400 - val_loss: 64.4028
# Epoch 15/200
# 13/13 - 0s - 1ms/step - loss: 63.9394 - val_loss: 63.1055
# Epoch 16/200
# 13/13 - 0s - 1ms/step - loss: 62.6387 - val_loss: 61.8081
# Epoch 17/200
# 13/13 - 0s - 1ms/step - loss: 61.3381 - val_loss: 60.5108
# Epoch 18/200
# 13/13 - 0s - 1ms/step - loss: 60.0374 - val_loss: 59.2135
# Epoch 19/200
# 13/13 - 0s - 1ms/step - loss: 58.7368 - val_loss: 57.9162
# Epoch 20/200
# 13/13 - 0s - 1ms/step - loss: 57.4361 - val_loss: 56.6188
# Epoch 21/200
# 13/13 - 0s - 1ms/step - loss: 56.1355 - val_loss: 55.3215
# Epoch 22/200
# 13/13 - 0s - 1ms/step - loss: 54.8349 - val_loss: 54.0242
# Epoch 23/200
# 13/13 - 0s - 1ms/step - loss: 53.5342 - val_loss: 52.7269
# Epoch 24/200
# 13/13 - 0s - 1ms/step - loss: 52.2336 - val_loss: 51.4296
# Epoch 25/200
# 13/13 - 0s - 1ms/step - loss: 50.9329 - val_loss: 50.1322
# Epoch 26/200
# 13/13 - 0s - 1ms/step - loss: 49.6323 - val_loss: 48.8349
# Epoch 27/200
# 13/13 - 0s - 1ms/step - loss: 48.3316 - val_loss: 47.5376
# Epoch 28/200
# 13/13 - 0s - 1ms/step - loss: 47.0310 - val_loss: 46.2403
# Epoch 29/200
# 13/13 - 0s - 1ms/step - loss: 45.7303 - val_loss: 44.9429
# Epoch 30/200
# 13/13 - 0s - 1ms/step - loss: 44.4297 - val_loss: 43.6456
# Epoch 31/200
# 13/13 - 0s - 1ms/step - loss: 43.1290 - val_loss: 42.3483
# Epoch 32/200
# 13/13 - 0s - 1ms/step - loss: 41.8284 - val_loss: 41.0510
# Epoch 33/200
# 13/13 - 0s - 1ms/step - loss: 40.5277 - val_loss: 39.7537
# Epoch 34/200
# 13/13 - 0s - 1ms/step - loss: 39.2271 - val_loss: 38.4563
# Epoch 35/200
# 13/13 - 0s - 1ms/step - loss: 37.9264 - val_loss: 37.1590
# Epoch 36/200
# 13/13 - 0s - 2ms/step - loss: 36.6258 - val_loss: 35.8617
# Epoch 37/200
# 13/13 - 0s - 2ms/step - loss: 35.3251 - val_loss: 34.5644
# Epoch 38/200
# 13/13 - 0s - 1ms/step - loss: 34.0245 - val_loss: 33.2671
# Epoch 39/200
# 13/13 - 0s - 1ms/step - loss: 32.7239 - val_loss: 31.9697
# Epoch 40/200
# 13/13 - 0s - 1ms/step - loss: 31.4232 - val_loss: 30.6724
# Epoch 41/200
# 13/13 - 0s - 1ms/step - loss: 30.1226 - val_loss: 29.3751
# Epoch 42/200
# 13/13 - 0s - 1ms/step - loss: 28.8219 - val_loss: 28.0778
# Epoch 43/200
# 13/13 - 0s - 1ms/step - loss: 27.5213 - val_loss: 26.7805
# Epoch 44/200
# 13/13 - 0s - 1ms/step - loss: 26.2206 - val_loss: 25.4831
# Epoch 45/200
# 13/13 - 0s - 1ms/step - loss: 24.9200 - val_loss: 24.1858
# Epoch 46/200
# 13/13 - 0s - 1ms/step - loss: 23.6193 - val_loss: 22.8885
# Epoch 47/200
# 13/13 - 0s - 1ms/step - loss: 22.3187 - val_loss: 21.5912
# Epoch 48/200
# 13/13 - 0s - 1ms/step - loss: 21.0180 - val_loss: 20.2939
# Epoch 49/200
# 13/13 - 0s - 1ms/step - loss: 19.7174 - val_loss: 18.9965
# Epoch 50/200
# 13/13 - 0s - 1ms/step - loss: 18.4167 - val_loss: 17.6992
# Epoch 51/200
# 13/13 - 0s - 1ms/step - loss: 17.1161 - val_loss: 16.4019
# Epoch 52/200
# 13/13 - 0s - 1ms/step - loss: 15.8154 - val_loss: 15.1046
# Epoch 53/200
# 13/13 - 0s - 1ms/step - loss: 14.5148 - val_loss: 13.8073
# Epoch 54/200
# 13/13 - 0s - 1ms/step - loss: 13.2141 - val_loss: 12.5099
# Epoch 55/200
# 13/13 - 0s - 1ms/step - loss: 11.9135 - val_loss: 11.2126
# Epoch 56/200
# 13/13 - 0s - 1ms/step - loss: 10.6157 - val_loss: 9.9362
# Epoch 57/200
# 13/13 - 0s - 1ms/step - loss: 9.3779 - val_loss: 8.8018
# Epoch 58/200
# 13/13 - 0s - 1ms/step - loss: 8.3463 - val_loss: 7.7261
# Epoch 59/200
# 13/13 - 0s - 1ms/step - loss: 7.3278 - val_loss: 6.6187
# Epoch 60/200
# 13/13 - 0s - 1ms/step - loss: 6.2977 - val_loss: 5.5295
# Epoch 61/200
# 13/13 - 0s - 1ms/step - loss: 5.2705 - val_loss: 4.4549
# Epoch 62/200
# 13/13 - 0s - 1ms/step - loss: 4.2550 - val_loss: 3.3849
# Epoch 63/200
# 13/13 - 0s - 1ms/step - loss: 3.2544 - val_loss: 2.4859
# Epoch 64/200
# 13/13 - 0s - 1ms/step - loss: 2.2987 - val_loss: 1.7161
# Epoch 65/200
# 13/13 - 0s - 1ms/step - loss: 1.4674 - val_loss: 1.2217
# Epoch 66/200
# 13/13 - 0s - 1ms/step - loss: 0.9253 - val_loss: 1.1547
# Epoch 67/200
# 13/13 - 0s - 1ms/step - loss: 0.8484 - val_loss: 1.1853
# Epoch 68/200
# 13/13 - 0s - 1ms/step - loss: 0.8500 - val_loss: 1.1694
# Epoch 69/200
# 13/13 - 0s - 1ms/step - loss: 0.8436 - val_loss: 1.1459
# Epoch 70/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1436
# Epoch 71/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1463
# Epoch 72/200
# 13/13 - 0s - 1ms/step - loss: 0.8418 - val_loss: 1.1483
# Epoch 73/200
# 13/13 - 0s - 1ms/step - loss: 0.8418 - val_loss: 1.1489
# Epoch 74/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1473
# Epoch 75/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1483
# Epoch 76/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1481
# Epoch 77/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1475
# Epoch 78/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1468
# Epoch 79/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1480
# Epoch 80/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1478
# Epoch 81/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1488
# Epoch 82/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1473
# Epoch 83/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1480
# Epoch 84/200
# 13/13 - 0s - 1ms/step - loss: 0.8418 - val_loss: 1.1483
# Epoch 85/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1481
# Epoch 86/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1474
# Epoch 87/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1481
# Epoch 88/200
# 13/13 - 0s - 2ms/step - loss: 0.8419 - val_loss: 1.1482
# Epoch 89/200
# 13/13 - 0s - 2ms/step - loss: 0.8419 - val_loss: 1.1485
# Epoch 90/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1482
# Epoch 91/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1475
# Epoch 92/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1487
# Epoch 93/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1486
# Epoch 94/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1480
# Epoch 95/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1488
# Epoch 96/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1471
# Epoch 97/200
# 13/13 - 0s - 2ms/step - loss: 0.8420 - val_loss: 1.1477
# Epoch 98/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1480
# Epoch 99/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1477
# Epoch 100/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1487
# Epoch 101/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1488
# Epoch 102/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1469
# Epoch 103/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1479
# Epoch 104/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1478
# Epoch 105/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1488
# Epoch 106/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1491
# Epoch 107/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1471
# Epoch 108/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1482
# Epoch 109/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1480
# Epoch 110/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1492
# Epoch 111/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1472
# Epoch 112/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1484
# Epoch 113/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1483
# Epoch 114/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1475
# Epoch 115/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1485
# Epoch 116/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1484
# Epoch 117/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1482
# Epoch 118/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1461
# Epoch 119/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1473
# Epoch 120/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1492
# Epoch 121/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1496
# Epoch 122/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1473
# Epoch 123/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1485
# Epoch 124/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1484
# Epoch 125/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1476
# Epoch 126/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1487
# Epoch 127/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1467
# Epoch 128/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1478
# Epoch 129/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1477
# Epoch 130/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1489
# Epoch 131/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1490
# Epoch 132/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1467
# Epoch 133/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1479
# Epoch 134/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1493
# Epoch 135/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1462
# Epoch 136/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1472
# Epoch 137/200
# 13/13 - 0s - 1ms/step - loss: 0.8419 - val_loss: 1.1493
# Epoch 138/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1496
# Epoch 139/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1472
# Epoch 140/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1486
# Epoch 141/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1484
# Epoch 142/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1475
# Epoch 143/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1486
# Epoch 144/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1486
# Epoch 145/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1464
# Epoch 146/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1475
# Epoch 147/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1476
# Epoch 148/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1491
# Epoch 149/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1469
# Epoch 150/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1483
# Epoch 151/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1482
# Epoch 152/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1473
# Epoch 153/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1491
# Epoch 154/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1491
# Epoch 155/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1481
# Epoch 156/200
# 13/13 - 0s - 1ms/step - loss: 0.8420 - val_loss: 1.1493
# Epoch 157/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1493
# Epoch 158/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1469
# Epoch 159/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1481
# Epoch 160/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1482
# Epoch 161/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1473
# Epoch 162/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1484
# Epoch 163/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1493
# Epoch 164/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1490
# Epoch 165/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1480
# Epoch 166/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1491
# Epoch 167/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1491
# Epoch 168/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1464
# Epoch 169/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1478
# Epoch 170/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1478
# Epoch 171/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1493
# Epoch 172/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1493
# Epoch 173/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1468
# Epoch 174/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1481
# Epoch 175/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1483
# Epoch 176/200
# 13/13 - 0s - 1ms/step - loss: 0.8424 - val_loss: 1.1473
# Epoch 177/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1493
# Epoch 178/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1492
# Epoch 179/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1480
# Epoch 180/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1494
# Epoch 181/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1494
# Epoch 182/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1466
# Epoch 183/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1481
# Epoch 184/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1479
# Epoch 185/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1469
# Epoch 186/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1479
# Epoch 187/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1488
# Epoch 188/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1484
# Epoch 189/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1472
# Epoch 190/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1493
# Epoch 191/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1493
# Epoch 192/200
# 13/13 - 0s - 1ms/step - loss: 0.8424 - val_loss: 1.1482
# Epoch 193/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1490
# Epoch 194/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1465
# Epoch 195/200
# 13/13 - 0s - 1ms/step - loss: 0.8423 - val_loss: 1.1477
# Epoch 196/200
# 13/13 - 0s - 1ms/step - loss: 0.8422 - val_loss: 1.1477
# Epoch 197/200
# 13/13 - 0s - 1ms/step - loss: 0.8421 - val_loss: 1.1494
# Epoch 198/200
# 13/13 - 0s - 1ms/step - loss: 0.8424 - val_loss: 1.1467
# Epoch 199/200
# 13/13 - 0s - 2ms/step - loss: 0.8422 - val_loss: 1.1483
# Epoch 200/200
# 13/13 - 0s - 2ms/step - loss: 0.8423 - val_loss: 1.1482
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Resultados para NNL:
# Métrica     TEST
#     MAE 0.793746
#     MSE 1.783213
#      R² 0.965765

# %% [markdown]
# ##### **Adding Non-Linearity**
#
# We will make some modifications and create a different, slightly more complex model to see if we can improve performance.
#
# As you may recall, not all problems have a linear solution. A basic neural network like ours is limited to performing linear combinations of numbers (sums and multiplications), meaning it transforms the input into the output using the formula $y = Wx + b$.
#
# To introduce non-linearity, we need to incorporate **non-linear activation functions**. These functions are applied to the output of each layer, allowing the network to learn more complex relationships between inputs and outputs. Some common activation functions include `ReLU`, `sigmoid`, and `tanh`. By adding these functions, the network can approximate non-linear functions and solve more challenging problems.
#
# <center>
#     <div style="border-radius:5px; padding:10px; background:white; max-width:900px">
#         <img src="https://i.imgur.com/e7kd5fs.png">
#     </div>
# </center>
#
# Our current model has only one layer, the output layer. If we were to apply any of these functions to this layer, not only would we fail to introduce non-linearity, but we would also significantly restrict the range of values the model can predict.
#
# For example, if we only add a `sigmoid` function to the final layer, we would have a linear model whose output will **always** be limited to the range between 0 and 1. This is not ideal for our regression problem.
#
# To achieve non-linearity and avoid this limitation—while allowing the model to predict in a range of values between $(-\infty , \infty)$—we will add a hidden (or intermediate) layer and apply activation in this layer. This way, the final layer can generate outputs without the restrictions imposed by the activation function while still achieving non-linearity.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Exercise:</b> Create, within the provided function, a new neural network, but this time with two layers, the hidden one of <b>size 10</b> and with an activation function of <code>tanh</code> to add non-linearity.
#     <br>
#     Check the documentation for the <a href="https://keras.io/api/layers/core_layers/dense/"><code>Dense()</code></a> layer.
#     <hr>
#     Find the best <code>learning_rate</code> and evaluate on test with the best version. Fill in both tables.
# </div>
#
# <center>
#
# | Model                    | MAE Train  | MAE Val |
# |---------------------------|------------|---------|
# | *Neural Network (lr=0.001)* |            |         |
# | *Neural Network (lr=0.05)*  |            |         |
# | *Neural Network (lr=0.1)*   |            |         |
#
# <center>
# <br>
# <center>
#
# | Model                   | MAE Test  | MSE Test  | R² Test  |
# |--------------------------|-----------|-----------|----------|
# | *Baseline*               | 5.882     | 52.489    | -0.008   |
# | *Linear*                 | 1.056     |  2.298    |  0.956   |
# | *KNN*                    | 0.820     |  1.801    |  0.965   |
# | *Decision Trees*         | 1.110     |  3.575    |  0.931   |
# | *SVR*                    | 0.735     |  1.738    |  0.967   |
# | *Linear Neural Network*  |           |           |          |
# | *Non-Linear Neural Network* |        |           |          |
#
# </center>

# %%
def neural_network_two(learning_rate):
    # Create and compile the model
    model = Sequential()  
    model.add(Input(shape = (1,)))  
    model.add(Dense(10, activation='sigmoid'))
    model.add(Dense(1, name = 'output_layer'))

    optim = Adam(learning_rate = learning_rate)
    model.compile(loss = 'mean_absolute_error', optimizer = optim, metrics=['mae'])
    return model

# Create the network from scratch
model_2 = neural_network_two(learning_rate = 1.0)

# Your code here
history = model_2.fit(Xtr_s, ytr, validation_split = 0.2, batch_size = 64, epochs = 200, verbose = 0)
plot_loss_history(history)
y_pred = model_2.predict(Xte_s, verbose=0)
evaluate_model(yte, y_pred, 'NN-NL')
# Out:
# Resultados para NN-NL:
# Métrica     TEST
#     MAE 0.809227
#     MSE 1.687630
#      R² 0.967600

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Exercise:</b> Which model would you choose?
# </div>

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### **2.4. Multiple Inputs**

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Exercise:</b> Create a pair of networks capable of predicting <i>LapTime</i> from <i>SpeedI1</i>, <i>SpeedI2</i>, <i>SpeedFL</i>, <i>SpeedST</i>, and <i>TyreLife</i>. Adjust the hyperparameters for each model.
# </div>
#
# <center>
#
# | Model                    | MAE Test  | MSE Test  | R² Test  |
# |--------------------------|-----------|-----------|----------|
# | *Baseline*               | 5.858     | 54.094    | -0.008   |
# | *Linear*                 | 0.932     | 1.678     | 0.969    |
# | *KNN*                    | 0.785     | 1.743     | 0.968    |
# | *Decision Trees*         | 0.899     | 1.841     | 0.966    |
# | *SVR*                    | 0.938     | 2.724     | 0.949    |
# | *Neural Network 1*       |           |           |          |
# | *Neural Network 2*       |           |           |          |
#
# </center>

# %%
data_lap_time = data[['LapTime', 'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'TyreLife']]
data_lap_time = data_lap_time.dropna()
data_lap_time['LapTime'] = data_lap_time['LapTime'].dt.total_seconds()

X = data_lap_time[['SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'TyreLife']]
Y = data_lap_time['LapTime']

Xtr, Xte, ytr, yte = train_test_split(X, Y, random_state = seed, test_size = .2)

standardizer = StandardScaler()
Xtr_s = standardizer.fit_transform(Xtr)
Xte_s = standardizer.transform(Xte)

# Baseline mean
baseline_mean = DummyRegressor(strategy = 'mean')
baseline_mean.fit(Xtr_s, ytr)
preds_test = baseline_mean.predict(Xte_s)
evaluate_model(yte, preds_test, 'Baseline')

# Linear Regression
model_linear = LinearRegression()
model_linear.fit(Xtr_s, ytr)
preds_test = model_linear.predict(Xte_s)
evaluate_model(yte, preds_test, 'Linear')

# KNN
model_knn = KNeighborsRegressor()
model_knn.fit(Xtr_s, ytr)
preds_test = model_knn.predict(Xte_s)
evaluate_model(yte, preds_test, 'KNN')

# Decision Trees
model_tree = DecisionTreeRegressor()
model_tree.fit(Xtr_s, ytr)
preds_test = model_tree.predict(Xte_s)
evaluate_model(yte, preds_test, 'Decision Trees')

# SVR
model_svr = SVR()
model_svr.fit(Xtr_s, ytr)
preds_test = model_svr.predict(Xte_s)
evaluate_model(yte, preds_test, 'SVR')

def neural_network_three(learning_rate):
    # Create and compile the model
    model = Sequential()  
    model.add(Input(shape = (5,)))  
    model.add(Dense(10, activation='sigmoid'))
    model.add(Dense(1, name = 'output_layer'))

    optim = Adam(learning_rate = learning_rate)
    model.compile(loss = 'mean_absolute_error', optimizer = optim, metrics=['mae'])
    return model
model_3 = neural_network_three(learning_rate = 1.0)
history = model_3.fit(Xtr_s, ytr, validation_split = 0.2, batch_size = 16, epochs = 200, verbose = 0)
plot_loss_history(history)
y_pred = model_3.predict(Xte_s, verbose=0)
evaluate_model(yte, y_pred, 'NN-NL')
# Out:
# Resultados para Baseline:
# Métrica      TEST
#     MAE  5.858304
#     MSE 54.093475
#      R² -0.007702
#
# Resultados para Linear:
# Métrica     TEST
#     MAE 0.932171
#     MSE 1.677874
#      R² 0.968743
#
# Resultados para KNN:
# Métrica     TEST
#     MAE 0.785469
#     MSE 1.742535
#      R² 0.967538
#
# Resultados para Decision Trees:
# Métrica     TEST
#     MAE 0.962370
#     MSE 2.133517
#      R² 0.960255
#
# Resultados para SVR:
# Métrica     TEST
#     MAE 0.938374
#     MSE 2.723605
#      R² 0.949262
# /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages/sklearn/linear_model/_base.py:293: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages/sklearn/linear_model/_base.py:293: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/samuel/Código/University/venv_stable/lib/python3.11/site-packages/sklearn/linear_model/_base.py:293: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x125ed2160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Resultados para NN-NL:
# Métrica      TEST
#     MAE  2.369609
#     MSE 12.645051
#      R²  0.764437

# %%
# Your code here
