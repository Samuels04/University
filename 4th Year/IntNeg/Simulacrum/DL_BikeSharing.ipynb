# %%
# Libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %% [markdown]
# A dataset related to bike-sharing demand is provided, containing 731 daily records and 16 features. It was
# compiled to analyze and predict the number of bike rentals in a bike-sharing system based on the following
# features:

# %% [markdown]
# #### Dataset

# %%
# Bike Sharing dataset
# df_bs = pd.read_csv('https://raw.githubusercontent.com/AIC-Uniovi/Sistemas-Inteligentes/refs/heads/main/datasets/bike_sharing.csv')
df_bs = pd.read_csv('bike_sharing.csv')
df_bs.head(5)
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# #### EDA & Visualization
#
# Explore the dataset: 1.1 Describe the dataset (inlcude its shape and data types of its features) 1.2 Calculate the correaltion matrix for the numerical features 1.34 Create a plot showing the distribution of the Daily Rentals by Year. Use a histogram with KDE overlay for each year.

# %%
# Description of the dataset (shape + features dtypes)

# Your code here
df_bs.describe()
print(df_bs.shape)
print(df_bs.dtypes)
# Out:
# (731, 16)
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
# Distribution of Daily Rentals (cnt) by Year (yr)

# Your code here
plt.figure(figsize=(12,6))
hist = sns.histplot(data=df_bs, x = 'cnt', hue='yr', kde=True)

# %% [markdown]
# #### Data Preprocessing
# 2.- Verify that there are not missing values in the dataset. Then, replace the outliers in the hum and windspeed features: identify the values outside the 25th and 75th percentiles and replace them with the mean value within the normal range.
#
# 3.- Prepare the dataset for modelling: 3.1 Split the data into X and Y, X containing the features and Y containing the target variable cnt 3.2 Standardize the numerical features with StandardScaler 3.3 Apply label encoding to the ca tegorical features

# %%
# 2.- NA-values
# Your code here

for col in df_bs.columns.to_list():
    print(f"In column {col} there are {df_bs[col].isna().sum()} missing values")
# Out:
# In column instant there are 0 missing values
# In column dteday there are 0 missing values
# In column season there are 0 missing values
# In column yr there are 0 missing values
# In column mnth there are 0 missing values
# In column holiday there are 0 missing values
# In column weekday there are 0 missing values
# In column workingday there are 0 missing values
# In column weathersit there are 0 missing values
# In column temp there are 0 missing values
# In column atemp there are 0 missing values
# In column hum there are 0 missing values
# In column windspeed there are 0 missing values
# In column casual there are 0 missing values
# In column registered there are 0 missing values
# In column cnt there are 0 missing values

# %%
# Feature Selection + Target
features = ['season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed']
target = 'cnt'

# Your code here

# %%
# Standardize numerical features
numerical_features = ['temp', 'atemp', 'hum', 'windspeed']

# Your code here

# %%
# Label-Encode categorical features
categorical_features = ['season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday', 'weathersit']

# Your code here

# %%
# Train-vs-Test split

# Your code here

# %% [markdown]
# # What type of problem is this?

# %% [markdown]
# Your ``answer`` here.

# %% [markdown]
# #### Machine Learning Model

# %%
# Machine Learning modeling

# Your code here

# %%
# Which is the best performing model?

# %% [markdown]
# Your ``answer`` here
#
# <center>
#
# | Model               |    MAE    |      MSE       |   R²   |
# |---------------------|-----------|----------------|--------|
# | XX                  |  XX       | XX             |     XX |
# | XX                  |  XX       | XX             |     XX |
# | XX                  |  XX       | XX             |     XX |
# | XX                  |  XX       | XX             |     XX |
#
# <center>

# %% [markdown]
# #### Deep Learning Model

# %%
# Deep Learning modeling

# Neural Network model (#1)

# Model Design

# Your code here

# %%
# Deep Learning modeling

# Neural Network model (#1)

# Compilation + Training

# Your code here


# Loss-vs-MSE Training curves
def training_curves(history, model, metric):
    fig = plt.figure(figsize = (10, 4))
    ax1 = fig.gca()
    ax1.set_facecolor('whitesmoke')
    ax1.plot(history.history['loss'], label = 'Loss', color = 'steelblue', linewidth = 2.6)
    ax1.set_ylabel('Loss', fontsize = 10)
    ax1.tick_params(axis = 'y', labelsize = 10)
    ax2 = ax1.twinx()
    ax2.plot(history.history[metric], label = metric.upper(), color = 'crimson', linewidth = 2.6)
    ax2.set_ylabel(metric.upper(), fontsize = 10)
    ax2.tick_params(axis = 'y', labelsize = 10)
    ax1.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:.0f}'))
    ax2.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:.0f}'))
    ax1.set_xlabel('Epoch', fontsize = 10)
    ax1.tick_params(axis = 'x', labelsize = 10)
    plt.title(f'{model} - Loss-vs-{metric.upper()} Training curves', fontsize = 12, fontweight = 'bold')
    plt.grid(linestyle = '--')
    lines1, labels1 = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    fig.legend(lines1 + lines2, labels1 + labels2, loc = 'upper right', bbox_to_anchor = (0.94, 0.86), fontsize = 10)
    legend.get_frame().set_linewidth(0.5);

# Your code here

# %%
#  Deep Learning modeling

# Neural Network model (#1)

# Model Prediction

# Your code here


# Evaluation

# Your code here

# %%
# Deep Learning modeling

# Neural Network model (#2)

# Model Design

# Your code here

# %%
#  Deep Learning modeling

# Neural Network model (#2)

# Compilation + Training

# Your code here


# Loss-vs-MSE Training curves

# Your code here

# %%
# Deep Learning modeling

# Neural Network model (#2)

# Model Prediction

# Your code here


# Evaluation

# Your code here

# %%
# Which is the best performing model?

# %% [markdown]
# Your ``answer`` here
#
# <center>
#
# | Model               |    MAE    |      MSE       |   R²   |
# |---------------------|-----------|----------------|--------|
# | XX                  |  XX       | XX             |     XX |
# | XX                  |  XX       | XX             |     XX |
# | XX                  |  XX       | XX             |     XX |
# | XX                  |  XX       | XX             |     XX |
# | XX                  |  XX       | XX             |     XX |
#
# <center>
