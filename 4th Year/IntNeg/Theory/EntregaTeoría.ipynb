# %% [markdown]
# # Comparación de técnicas de imputación de valores perdidos

# %% [markdown]
# ## Importaciones y carga del dataset

# %%
import pandas as pd

df = pd.read_csv("/Users/samuel/Código/titanic_dataset.csv")
print("Dataset creado con éxito")
print("Tiene este tamaño: ", df.shape)
print("Tiene estas columnas: ", df.columns)
# Out:
# Dataset importado y creado con éxito
# Tiene este tamaño:  (1309, 14)
# Tiene estas columnas:  Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %% [markdown]
# ## Imputación básica
